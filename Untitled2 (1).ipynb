# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("Draw Wire Analog Count Reading.csv")
print(data.head(10))
# Out:
#    Distance in MM   FWD1   RVS2   FWD3   RVS4   FWD5   RVS6   FWD7   RVS8  \
# 0               0      0     17     18     12     12     13     12     12
# 1             100   1102   1126   1154   1143   1127   1138   1131   1160
# 2             200   2255   2284   2279   2285   2274   2297   2262   2297
# 3             300   3380   3402   3385   3397   3402   3385   3385   3397
# 4             400   4549   4549   4544   4515   4509   4521   4509   4526
# 5             500   5667   5665   5679   5667   5662   5655   5638   5666
# 6             600   6806   6812   6829   6830   6794   6794   6807   6806
# 7             700   7968   7981   7958   7987   7947   7952   7975   7964
# 8             800   9172   9154   9184   9161   9160   9138   9132   9165
# 9             900  10334  10329  10323  10318  10329  10317  10323  10306
#
#     FWD9  ...  RVS20  FWD21  RVS22  FWD23  RVS24  FWD25  RVS26    Min    Max  \
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Distance in MM  27 non-null     int64
#  1   FWD1            27 non-null     int64
#  2   RVS2            27 non-null     int64
#  3   FWD3            27 non-null     int64
#  4   RVS4            27 non-null     int64
#  5   FWD5            27 non-null     int64
#  6   RVS6            27 non-null     int64
#  7   FWD7            27 non-null     int64
#  8   RVS8            27 non-null     int64
#  9   FWD9            27 non-null     int64
#  10  RVS10           27 non-null     int64
#  11  FWD11           27 non-null     int64
#  12  RVS12           27 non-null     int64
#  13  FWD13           27 non-null     int64
#  14  RVS14           27 non-null     int64
#  15  FWD15           27 non-null     int64
#  16  RVS16           27 non-null     int64
# ...

# %%
Dist = data['Distance in MM'].tolist()
print(Dist)
# Out:
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600]

# %%
print(data.max())

# %%
FWD_1 = data['FWD1'].tolist()
print(FWD_1)
# Out:
# [0, 1102, 2255, 3380, 4549, 5667, 6806, 7968, 9172, 10334, 11540, 12726, 13928, 15157, 16373, 17620, 18906, 20182, 21470, 22773, 24100, 25448, 26797, 28154, 29556, 30994, 32395]

# %%
xpoints = np.array(['Distance in MM'])
ypoints = np.array(['FWD1'])

plt.plot(xpoints, ypoints)
plt.show()

# %%
plt.scatter(xpoints, ypoints, c ="pink",
            linewidths = 2,
            marker ="s",
            edgecolor ="green",
            s = 50)

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
data.plot(x='Distance in MM', y='FWD1', style='o')
plt.title('FWD1 vs Distance')
plt.xlabel('Distance')
plt.ylabel('FWD1')
plt.show()

# %%
data.plot.line(x='Distance in MM', y='FWD1')
plt.show()

# %%
data.plot.line(x='Distance in MM',y=['FWD1','RVS2','FWD3'], figsize=(10,6))
plt.show()

# %%
data.plot.line(x='Distance in MM',y=['RVS2'], figsize=(10,6))
plt.show()

# %%
data.plot.line(x='Distance in MM',y=['FWD3'], figsize=(10,6))
plt.show()

# %%
data.plot(kind='bar',x='Distance in MM', y='FWD1')
plt.show()

# %%
data.plot(kind='bar',x='Distance in MM', y=['FWD1','RVS2','FWD3'],figsize=(15,6))
plt.show()

# %%
data.plot(kind='barh',x='Distance in MM', y=['RVS2'],figsize=(15,6))
plt.show()

# %%
data.plot(kind='barh', x='Distance in MM', y=['FWD1', 'RVS2','FWD3'],figsize=(10,15))
plt.show()

# %%
data.plot(kind='bar', stacked = 'true',figsize=(10,15))
# Out:
# <Axes: >

# %%
data.plot(kind='line', figsize=(10,6))
# Out:
# <Axes: >

# %%
data[['FWD1','RVS2']].plot(kind='hist', bins=25, alpha=0.6, figsize=(10,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
data[['FWD1', 'RVS2']].plot(kind='hist', bins=25, alpha=0.6, stacked=True, figsize=(9,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot(kind='area', figsize=(10,6))
# Out:
# <Axes: >

# %%
data.plot(kind='box', stacked = 'false',figsize=(10,6))
# Out:
# <Axes: >

# %%
data.plot(kind='area', stacked = 'true',figsize=(10,6))
# Out:
# <Axes: >
